# %% [markdown]
# # Entrenamiento de un modelo para clasificación de mascotas

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import json
import joblib

# %%
pets = pd.read_csv("pets_v2.csv")

# %%
pets.head()
# Out:
#    weight_kg  height_cm eye_color fur_length pet_type
# 0        6.5       27.8     green       long      cat
# 1        1.3       26.5      gray      short   rabbit
# 2        4.1       15.9      gray      short   rabbit
# 3        9.1       23.3     green       long      cat
# 4        3.2       27.7      gray      short   rabbit

# %%
pets["eye_color"].unique()
# Out:
# array(['green', 'gray', 'brown', 'blue'], dtype=object)

# %%
pets["fur_length"].unique()
# Out:
# array(['long', 'short', 'medium'], dtype=object)

# %%
X = pets.drop("pet_type", axis=1)
y = pets["pet_type"]

# Codifica las columnas categoricas
X_encoded = pd.get_dummies(X, columns=["eye_color", "fur_length"])

# %%
X_encoded
# Out:
#      weight_kg  height_cm  eye_color_blue  eye_color_brown  eye_color_gray  \
# 0          6.5       27.8           False            False           False
# 1          1.3       26.5           False            False            True
# 2          4.1       15.9           False            False            True
# 3          9.1       23.3           False            False           False
# 4          3.2       27.7           False            False            True
# ..         ...        ...             ...              ...             ...
# 195       25.1       79.3           False             True           False
# 196       19.2       63.4            True            False           False
# 197        8.2       20.3           False            False           False
# 198        7.6       28.3            True            False           False
# 199        5.6       37.8            True            False           False
#
#      eye_color_green  fur_length_long  fur_length_medium  fur_length_short
# 0               True             True              False             False
# 1              False            False              False              True
# 2              False            False              False              True
# 3               True             True              False             False
# 4              False            False              False              True
# ..               ...              ...                ...               ...
# 195            False             True              False             False
# 196            False            False              False              True
# 197             True            False              False              True
# 198            False            False               True             False
# 199            False            False              False              True
#
# [200 rows x 9 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2)

# %%
# Vamos a guardar las asignaciones de categorias para Streamlit
category_mapping = {
    "eye_color": pd.get_dummies(pets["eye_color"]).columns.tolist(),
    "fur_length": pd.get_dummies(pets["fur_length"]).columns.tolist()
}

with open("category_mapping.json", "w") as f:
    json.dump(category_mapping, f)

# %%
model = RandomForestClassifier()
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = model.predict(X_test)

accuracy_score(y_test, y_pred)
# Out:
# 0.975

# %%
joblib.dump(model, "pets_model.joblib")
# Out:
# ['pets_model.joblib']
