# %% [markdown]
# # Hadoop
#
# - Marco para la ejecución de aplicaciones en grandes clústeres.
#
# - El marco Hadoop proporciona de forma transparente a las aplicaciones tanto fiabilidad como movimiento de datos.
#
# - Hadoop implementa el paradigma computacional denominado **Map/Reduce**, donde la aplicación se divide en muchos fragmentos pequeños de trabajo, cada uno de los cuales puede ejecutarse o reejecutarse en cualquier nodo del clúster.
#
# - Proporciona un sistema de archivos distribuido (HDFS) que almacena los datos en los nodos de computación, proporcionando un ancho de banda agregado muy alto en todo el clúster.
#
# - Tanto MapReduce como el **HDFS** están diseñados para que los fallos de los nodos sean gestionados automáticamente.

# %% [markdown]
# ## Paso 1: Instalación de Haddoop

# %%
# !wget https://downloads.apache.org/hadoop/common/hadoop-3.3.6/hadoop-3.3.6.tar.gz
# Out:
# --2024-01-23 09:02:54--  https://downloads.apache.org/hadoop/common/hadoop-3.3.6/hadoop-3.3.6.tar.gz
# Resolving downloads.apache.org (downloads.apache.org)... 88.99.95.219, 135.181.214.104, 2a01:4f9:3a:2c57::2, ...
# Connecting to downloads.apache.org (downloads.apache.org)|88.99.95.219|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 730107476 (696M) [application/x-gzip]
# Saving to: ‘hadoop-3.3.6.tar.gz’
#
# hadoop-3.3.6.tar.gz 100%[===================>] 696.28M  14.3MB/s    in 51s
#
# 2024-01-23 09:03:46 (13.6 MB/s) - ‘hadoop-3.3.6.tar.gz’ saved [730107476/730107476]

# %% [markdown]
# utilizaremos el comando tar con los parámetros:
# - -x para extraer,
# - -z para descomprimir,
# - -f para especificar que estamos extrayendo de un archivo
#
# podremos añadir -v para la salida en detalle,

# %%
# !tar -xzf hadoop-3.3.6.tar.gz

# %% [markdown]
# Copiamos el directorio de hadoop en */usr/local*

# %%
# !cp -r hadoop-3.3.6/ /usr/local/

# %% [markdown]
# ## Step 2: Configurar el Hadoop JAVA HOME
#
# Hadoop requiere que se establezca la ruta de acceso a Java, ya sea como una variable de entorno o en el archivo de configuración de Hadoop.

# %% [markdown]
# 1. Buscamos cual es la dirección de Java en la máquina Google Colab

# %%
# !readlink -f /usr/bin/java | sed "s:bin/java::"
# Out:
# /usr/lib/jvm/java-11-openjdk-amd64/

# %% [markdown]
# 2. Establecemos mediante código Python el valor de esta variable

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64/"
#os.environ["PATH"] = os.environ["PATH"] + ":" + "/usr/local/hadoop-3.3.6/bin"

# %% [markdown]
# # Step 3: Ejecutando Hadoop

# %% [markdown]
# - Comprobamos la versión de Hadoop

# %%
# !/usr/local/hadoop-3.3.6/bin/hadoop version
# Out:
# Hadoop 3.3.6
# Source code repository https://github.com/apache/hadoop.git -r 1be78238728da9266a4f88195058f08fd012bf9c
# Compiled by ubuntu on 2023-06-18T08:22Z
# Compiled on platform linux-x86_64
# Compiled with protoc 3.7.1
# From source with checksum 5652179ad55f76cb287d9c633bb53bbd
# This command was run using /usr/local/hadoop-3.3.6/share/hadoop/common/hadoop-common-3.3.6.jar

# %% [markdown]
# # HDFS
#
# - Es un sistema de archivos distribuido.
# - HDFS es altamente tolerante a fallos y está diseñado para ser desplegado en hardware de bajo coste.
# - HDFS es adecuado para aplicaciones que manejan grandes conjuntos de datos.
# - HDFS proporciona interfaces para acercar las aplicaciones al lugar donde se encuentran los datos. El cálculo es mucho más eficiente cuando el tamaño del conjunto de datos es enorme.
# - HDFS consiste en un único NameNode con un número de DataNodes que gestionan el almacenamiento.
# - HDFS dispone de un espacio de nombres del sistema de archivos y permite que los datos del usuario se almacenen en archivos.
#   1. El NameNode divide un archivo en bloques almacenados en DataNodes.
#   2. El NameNode ejecuta operaciones como abrir, cerrar y renombrar archivos y directorios.
#   3. El NameNode secundario almacena la información del NameNode.
#   4.  Los DataNodes gestionan la creación, eliminación y replicación de bloques siguiendo instrucciones del NameNode.
#   5. La ubicación de las réplicas está optimizada para la fiabilidad de los datos, la disponibilidad y la utilización del ancho de banda de la red.
#   6. Los datos del usuario nunca pasan por el NameNode.
#
# - Los archivos en HDFS son de una sola escritura y tienen estrictamente un único proceso escritor en cualquier momento.
#
# - El DataNode no tiene conocimiento de los archivos de HDFS.

# %% [markdown]
# **NOTA: Las siguientes sentencias únicamente sirven para probar comandos básicos de HDFS no para gestionar una Infraestructura que en Google Colab no existe, en este caso el sistema de archivos HDFS es el mismo que el local**

# %% [markdown]
# ## Accesibilidad
#
# Todos los  [comandos HDFS](http://hadoop.apache.org/docs/stable/hadoop-project-dist/hadoop-common/FileSystemShell.html)  se invocan mediante el script *bin/hdfs* :
# ```shell
# hdfs [SHELL_OPTIONS] COMMAND [GENERIC_OPTIONS] [COMMAND_OPTIONS]
# ```
# ## Gestión de ficheros y directorios
# ```shell
# hdfs dfs -ls -h -R # lista de subdirectorios recuriva
# hdfs dfs -cp  # Copia de ficheros
# hdfs dfs -mv  # Movimiento de ficheros
# hdfs dfs -mkdir /foodir # Crear directorio llamado /foodir
# hdfs dfs -rm -r /foodir   # Borrar un directorio /foodir
# hdfs dfs -cat /foodir/myfile.txt # Ver los contenidos de un fichero /foodir/myfile.txt
# ```

# %% [markdown]
# - Listar el contenido de un directorio

# %%
# !/usr/local/hadoop-3.3.6/bin/hadoop fs -ls /content
# Out:
# Found 4 items
# drwxr-xr-x   - root root       4096 2024-01-19 14:19 /content/.config
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:08 /content/hadoop-3.3.6
# -rw-r--r--   1 root root  730107476 2023-06-25 23:35 /content/hadoop-3.3.6.tar.gz
# drwxr-xr-x   - root root       4096 2024-01-19 14:20 /content/sample_data

# %% [markdown]
# Crear el directorio *prueba*

# %%
# !/usr/local/hadoop-3.3.6/bin/hadoop fs -mkdir prueba
# Out:
# mkdir: `prueba': File exists
# Found 5 items
# drwxr-xr-x   - root root       4096 2024-01-19 14:19 .config
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:08 hadoop-3.3.6
# -rw-r--r--   1 root root  730107476 2023-06-25 23:35 hadoop-3.3.6.tar.gz
# drwxr-xr-x   - root root       4096 2024-01-23 09:09 prueba
# drwxr-xr-x   - root root       4096 2024-01-19 14:20 sample_data

# %% [markdown]
# Copiar en   HDFS :
# ```bash
# hdfs dfs -put user.txt
# ```

# %% [markdown]
# Comprobar:
# ```bash
# hdfs dfs -ls -R
# hdfs dfs -cat user.txt
# hdfs dfs -tail user.txt
# ```

# %%
#!/usr/local/hadoop-3.3.6/bin/hadoop fs -ls -R
#!/usr/local/hadoop-3.3.6/bin/hadoop fs -cat user.txt
#!/usr/local/hadoop-3.3.6/bin/hadoop fs -tail user.txt
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# -rw-r--r--   1 1000 1000       3714 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-common/jdiff/xml/changes/classes_index_changes.html
# -rw-r--r--   1 1000 1000       5478 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-common/jdiff/xml/changes/pkg_org.apache.hadoop.util.html
# -rw-r--r--   1 1000 1000       3153 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-common/jdiff/xml/changes/fields_index_additions.html
# -rw-r--r--   1 1000 1000      10236 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-common/jdiff/xml/changes/jdiff_statistics.html
# -rw-r--r--   1 1000 1000      20526 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-common/jdiff/xml/changes/alldiffs_index_all.html
# -rw-r--r--   1 1000 1000       8217 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-common/jdiff/xml/changes/org.apache.hadoop.fs.statistics.IOStatisticsSnapshot.html
# -rw-r--r--   1 1000 1000       1633 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-common/jdiff/xml/changes/classes_index_removals.html
# -rw-r--r--   1 1000 1000       5591 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-common/jdiff/xml/changes/pkg_org.apache.hadoop.util.functional.html
# -rw-r--r--   1 1000 1000       5749 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-common/jdiff/xml/changes/pkg_org.apache.hadoop.fs.html
# -rw-r--r--   1 1000 1000       3681 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-common/jdiff/xml/changes/methods_index_removals.html
# -rw-r--r--   1 1000 1000       1842 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-common/jdiff/xml/changes/classes_index_additions.html
# -rw-r--r--   1 1000 1000      13527 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-common/jdiff/xml/changes/methods_index_all.html
# -rw-r--r--   1 1000 1000       6886 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-common/jdiff/xml/changes/alldiffs_index_changes.html
# -rw-r--r--   1 1000 1000       8644 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-common/jdiff/xml/changes/org.apache.hadoop.fs.statistics.StreamStatisticNames.html
# -rw-r--r--   1 1000 1000       6489 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-common/jdiff/xml/changes/pkg_org.apache.hadoop.fs.statistics.html
# -rw-r--r--   1 1000 1000       6722 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-common/jdiff/xml/changes/org.apache.hadoop.util.functional.RemoteIterators.html
# -rw-r--r--   1 1000 1000       3922 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-common/jdiff/xml/changes/classes_index_all.html
# -rw-r--r--   1 1000 1000       6468 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-common/jdiff/xml/changes/org.apache.hadoop.fs.FileSystem.html
# -rw-r--r--   1 1000 1000       1613 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-common/jdiff/xml/changes/packages_index_additions.html
# -rw-r--r--   1 1000 1000       1598 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-common/jdiff/xml/changes/fields_index_changes.html
# -rw-r--r--   1 1000 1000      14008 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-common/jdiff/xml/changes/alldiffs_index_additions.html
# -rw-r--r--   1 1000 1000       2116 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-common/jdiff/xml/changes/packages_index_all.html
# -rw-r--r--   1 1000 1000       1612 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-common/jdiff/xml/changes/packages_index_removals.html
# -rw-r--r--   1 1000 1000       3817 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-common/jdiff/xml/changes/alldiffs_index_removals.html
# -rw-r--r--   1 1000 1000       1593 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-common/jdiff/xml/changes/constructors_index_additions.html
# -rw-r--r--   1 1000 1000      16028 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-common/jdiff/xml/changes/org.apache.hadoop.fs.FSBuilder.html
# -rw-r--r--   1 1000 1000       4192 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-common/jdiff/xml/changes/changes-summary.html
# -rw-r--r--   1 1000 1000       2059 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-common/jdiff/xml/changes/packages_index_changes.html
# -rw-r--r--   1 1000 1000       1599 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-common/jdiff/xml/changes/fields_index_removals.html
# -rw-r--r--   1 1000 1000       6053 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-common/jdiff/xml/changes/org.apache.hadoop.util.VersionInfo.html
# -rw-r--r--   1 1000 1000       2956 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-common/jdiff/xml/changes/methods_index_changes.html
# -rw-r--r--   1 1000 1000       8383 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-common/jdiff/xml/user_comments_for_Apache_Hadoop_Common_3.3.5_to_Apache_Hadoop_Common_3.3.6.xml
# -rw-r--r--   1 1000 1000       1519 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-common/jdiff/xml/changes.html
# -rw-r--r--   1 1000 1000    1728312 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-common/jdiff/xml/Apache_Hadoop_Common_3.3.6.xml
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api
# -rw-r--r--   1 1000 1000    3446072 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/index-all.html
# -rw-r--r--   1 1000 1000      12842 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/stylesheet.css
# -rw-r--r--   1 1000 1000     196485 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/overview-tree.html
# -rw-r--r--   1 1000 1000      87322 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/constant-values.html
# -rw-r--r--   1 1000 1000       1364 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/overview-frame.html
# -rw-r--r--   1 1000 1000       5193 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/overview-summary.html
# -rw-r--r--   1 1000 1000      65694 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/serialized-form.html
# -rw-r--r--   1 1000 1000        827 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/script.js
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/protocol
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/protocol/proto
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/protocol/proto/class-use
# -rw-r--r--   1 1000 1000      10023 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/protocol/proto/class-use/RouterProtocolProtos.RouterAdminProtocolService.BlockingInterface.html
# -rw-r--r--   1 1000 1000       8075 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/protocol/proto/class-use/RouterProtocolProtos.RouterAdminProtocolService.Stub.html
# -rw-r--r--   1 1000 1000       9445 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/protocol/proto/class-use/RouterProtocolProtos.RouterAdminProtocolService.Interface.html
# -rw-r--r--   1 1000 1000       7665 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/protocol/proto/class-use/RouterProtocolProtos.RouterAdminProtocolService.html
# -rw-r--r--   1 1000 1000       4993 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/protocol/proto/class-use/RouterProtocolProtos.html
# -rw-r--r--   1 1000 1000       7257 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/protocol/proto/package-summary.html
# -rw-r--r--   1 1000 1000      40583 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/protocol/proto/RouterProtocolProtos.RouterAdminProtocolService.BlockingInterface.html
# -rw-r--r--   1 1000 1000      77910 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/protocol/proto/RouterProtocolProtos.RouterAdminProtocolService.Stub.html
# -rw-r--r--   1 1000 1000       2034 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/protocol/proto/package-frame.html
# -rw-r--r--   1 1000 1000      43918 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/protocol/proto/RouterProtocolProtos.RouterAdminProtocolService.Interface.html
# -rw-r--r--   1 1000 1000       7189 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/protocol/proto/package-tree.html
# -rw-r--r--   1 1000 1000       7065 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/protocol/proto/package-use.html
# -rw-r--r--   1 1000 1000      61571 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/protocol/proto/RouterProtocolProtos.RouterAdminProtocolService.html
# -rw-r--r--   1 1000 1000      13147 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/protocol/proto/RouterProtocolProtos.html
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/utils
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/utils/class-use
# -rw-r--r--   1 1000 1000       5162 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/utils/class-use/ConsistentHashRing.html
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/class-use
# -rw-r--r--   1 1000 1000       5151 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/class-use/CachedRecordStore.html
# -rw-r--r--   1 1000 1000       5338 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/class-use/StateStoreConnectionMonitorService.html
# -rw-r--r--   1 1000 1000       5272 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/class-use/StateStoreCacheUpdateService.html
# -rw-r--r--   1 1000 1000      11237 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/class-use/StateStoreCache.html
# -rw-r--r--   1 1000 1000      18054 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/class-use/StateStoreUnavailableException.html
# -rw-r--r--   1 1000 1000       5129 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/class-use/StateStoreUtils.html
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/class-use
# -rw-r--r--   1 1000 1000      10804 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/class-use/GetNamespaceInfoRequest.html
# -rw-r--r--   1 1000 1000      14955 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/class-use/LeaveSafeModeResponse.html
# -rw-r--r--   1 1000 1000      17174 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/class-use/AddMountTableEntryRequest.html
# -rw-r--r--   1 1000 1000      12397 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/class-use/UpdateNamenodeRegistrationRequest.html
# -rw-r--r--   1 1000 1000      17088 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/class-use/GetDestinationResponse.html
# -rw-r--r--   1 1000 1000      16338 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/class-use/AddMountTableEntryResponse.html
# -rw-r--r--   1 1000 1000      15695 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/class-use/GetDisabledNameservicesResponse.html
# -rw-r--r--   1 1000 1000      15259 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/class-use/DisableNameserviceRequest.html
# -rw-r--r--   1 1000 1000      17343 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/class-use/UpdateMountTableEntryRequest.html
# -rw-r--r--   1 1000 1000      11807 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/class-use/GetNamespaceInfoResponse.html
# -rw-r--r--   1 1000 1000      17203 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/class-use/GetMountTableEntriesRequest.html
# -rw-r--r--   1 1000 1000      10966 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/class-use/GetRouterRegistrationsRequest.html
# -rw-r--r--   1 1000 1000      12040 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/class-use/RefreshSuperUserGroupsConfigurationResponse.html
# -rw-r--r--   1 1000 1000      14200 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/class-use/GetSafeModeRequest.html
# -rw-r--r--   1 1000 1000      11420 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/class-use/RouterHeartbeatResponse.html
# -rw-r--r--   1 1000 1000      11720 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/class-use/GetRouterRegistrationRequest.html
# -rw-r--r--   1 1000 1000      10993 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/class-use/GetRouterRegistrationsResponse.html
# -rw-r--r--   1 1000 1000      12049 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/class-use/GetNamenodeRegistrationsResponse.html
# -rw-r--r--   1 1000 1000      16462 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/class-use/GetMountTableEntriesResponse.html
# -rw-r--r--   1 1000 1000      10966 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/class-use/GetRouterRegistrationResponse.html
# -rw-r--r--   1 1000 1000      16490 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/class-use/RemoveMountTableEntryResponse.html
# -rw-r--r--   1 1000 1000      11763 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/class-use/UpdateNamenodeRegistrationResponse.html
# -rw-r--r--   1 1000 1000      14316 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/class-use/LeaveSafeModeRequest.html
# -rw-r--r--   1 1000 1000      17232 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/class-use/RemoveMountTableEntryRequest.html
# -rw-r--r--   1 1000 1000      14837 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/class-use/GetSafeModeResponse.html
# -rw-r--r--   1 1000 1000      17535 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/class-use/GetDestinationRequest.html
# -rw-r--r--   1 1000 1000      14956 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/class-use/EnterSafeModeResponse.html
# -rw-r--r--   1 1000 1000      11317 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/class-use/RefreshSuperUserGroupsConfigurationRequest.html
# -rw-r--r--   1 1000 1000      11713 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/class-use/NamenodeHeartbeatRequest.html
# -rw-r--r--   1 1000 1000      16498 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/class-use/UpdateMountTableEntryResponse.html
# -rw-r--r--   1 1000 1000      14734 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/class-use/GetDisabledNameservicesRequest.html
# -rw-r--r--   1 1000 1000      16620 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/class-use/RefreshMountTableEntriesRequest.html
# -rw-r--r--   1 1000 1000      15103 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/class-use/EnableNameserviceResponse.html
# -rw-r--r--   1 1000 1000      15368 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/class-use/DisableNameserviceResponse.html
# -rw-r--r--   1 1000 1000      11482 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/class-use/NamenodeHeartbeatResponse.html
# -rw-r--r--   1 1000 1000      11928 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/class-use/GetNamenodeRegistrationsRequest.html
# -rw-r--r--   1 1000 1000      11637 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/class-use/RouterHeartbeatRequest.html
# -rw-r--r--   1 1000 1000      15209 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/class-use/EnableNameserviceRequest.html
# -rw-r--r--   1 1000 1000      14317 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/class-use/EnterSafeModeRequest.html
# -rw-r--r--   1 1000 1000      16655 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/class-use/RefreshMountTableEntriesResponse.html
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use
# -rw-r--r--   1 1000 1000       5632 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use/GetNamespaceInfoRequestPBImpl.html
# -rw-r--r--   1 1000 1000       5841 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use/RefreshSuperUserGroupsConfigurationRequestPBImpl.html
# -rw-r--r--   1 1000 1000       5709 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use/GetDisabledNameservicesRequestPBImpl.html
# -rw-r--r--   1 1000 1000       5621 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use/GetDestinationResponsePBImpl.html
# -rw-r--r--   1 1000 1000       5665 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use/DisableNameserviceResponsePBImpl.html
# -rw-r--r--   1 1000 1000       5654 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use/DisableNameserviceRequestPBImpl.html
# -rw-r--r--   1 1000 1000       5687 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use/GetMountTableEntriesResponsePBImpl.html
# -rw-r--r--   1 1000 1000       5676 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use/GetMountTableEntriesRequestPBImpl.html
# -rw-r--r--   1 1000 1000       5720 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use/RefreshMountTableEntriesRequestPBImpl.html
# -rw-r--r--   1 1000 1000       5599 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use/LeaveSafeModeRequestPBImpl.html
# -rw-r--r--   1 1000 1000       5709 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use/GetRouterRegistrationsResponsePBImpl.html
# -rw-r--r--   1 1000 1000       5643 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use/GetNamespaceInfoResponsePBImpl.html
# -rw-r--r--   1 1000 1000       5753 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use/UpdateNamenodeRegistrationResponsePBImpl.html
# -rw-r--r--   1 1000 1000       5687 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use/RemoveMountTableEntryRequestPBImpl.html
# -rw-r--r--   1 1000 1000       5610 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use/LeaveSafeModeResponsePBImpl.html
# -rw-r--r--   1 1000 1000       5632 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use/RouterHeartbeatResponsePBImpl.html
# -rw-r--r--   1 1000 1000       5654 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use/AddMountTableEntryRequestPBImpl.html
# -rw-r--r--   1 1000 1000       5654 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use/NamenodeHeartbeatResponsePBImpl.html
# -rw-r--r--   1 1000 1000       5577 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use/GetSafeModeRequestPBImpl.html
# -rw-r--r--   1 1000 1000       5731 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use/GetNamenodeRegistrationsResponsePBImpl.html
# -rw-r--r--   1 1000 1000       5643 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use/FederationProtocolPBTranslator.html
# -rw-r--r--   1 1000 1000       5698 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use/UpdateMountTableEntryResponsePBImpl.html
# -rw-r--r--   1 1000 1000       5643 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use/NamenodeHeartbeatRequestPBImpl.html
# -rw-r--r--   1 1000 1000       5698 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use/GetRouterRegistrationResponsePBImpl.html
# -rw-r--r--   1 1000 1000       5621 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use/RouterHeartbeatRequestPBImpl.html
# -rw-r--r--   1 1000 1000       5643 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use/EnableNameserviceRequestPBImpl.html
# -rw-r--r--   1 1000 1000       5852 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use/RefreshSuperUserGroupsConfigurationResponsePBImpl.html
# -rw-r--r--   1 1000 1000       5698 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use/GetRouterRegistrationsRequestPBImpl.html
# -rw-r--r--   1 1000 1000       5610 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use/EnterSafeModeResponsePBImpl.html
# -rw-r--r--   1 1000 1000       5720 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use/GetDisabledNameservicesResponsePBImpl.html
# -rw-r--r--   1 1000 1000       5687 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use/UpdateMountTableEntryRequestPBImpl.html
# -rw-r--r--   1 1000 1000       5654 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use/EnableNameserviceResponsePBImpl.html
# -rw-r--r--   1 1000 1000       5742 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use/UpdateNamenodeRegistrationRequestPBImpl.html
# -rw-r--r--   1 1000 1000       5599 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use/EnterSafeModeRequestPBImpl.html
# -rw-r--r--   1 1000 1000       5698 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use/RemoveMountTableEntryResponsePBImpl.html
# -rw-r--r--   1 1000 1000       5665 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use/AddMountTableEntryResponsePBImpl.html
# -rw-r--r--   1 1000 1000       5720 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use/GetNamenodeRegistrationsRequestPBImpl.html
# -rw-r--r--   1 1000 1000       5588 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use/GetSafeModeResponsePBImpl.html
# -rw-r--r--   1 1000 1000       5687 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use/GetRouterRegistrationRequestPBImpl.html
# -rw-r--r--   1 1000 1000       5610 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use/GetDestinationRequestPBImpl.html
# -rw-r--r--   1 1000 1000       5731 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/protocol/impl/pb/class-use/RefreshMountTableEntriesResponsePBImpl.html
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/records
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/records/class-use
# -rw-r--r--   1 1000 1000      11580 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/records/class-use/DisabledNameservice.html
# -rw-r--r--   1 1000 1000      13986 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/records/class-use/QueryResult.html
# -rw-r--r--   1 1000 1000      37058 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/records/class-use/MembershipState.html
# -rw-r--r--   1 1000 1000      16967 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/records/class-use/StateStoreVersion.html
# -rw-r--r--   1 1000 1000      16174 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/records/class-use/MembershipStats.html
# -rw-r--r--   1 1000 1000      73065 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/records/class-use/BaseRecord.html
# -rw-r--r--   1 1000 1000      30302 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/records/class-use/RouterState.html
# -rw-r--r--   1 1000 1000      45151 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/records/class-use/MountTable.html
# -rw-r--r--   1 1000 1000      14651 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/records/class-use/Query.html
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/records/impl
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/records/impl/pb
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/records/impl/pb/class-use
# -rw-r--r--   1 1000 1000      34158 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/records/impl/pb/class-use/PBRecord.html
# -rw-r--r--   1 1000 1000       5533 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/records/impl/pb/class-use/MembershipStatePBImpl.html
# -rw-r--r--   1 1000 1000       5478 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/records/impl/pb/class-use/MountTablePBImpl.html
# -rw-r--r--   1 1000 1000       5555 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/records/impl/pb/class-use/StateStoreVersionPBImpl.html
# -rw-r--r--   1 1000 1000       5489 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/records/impl/pb/class-use/RouterStatePBImpl.html
# -rw-r--r--   1 1000 1000       5533 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/records/impl/pb/class-use/MembershipStatsPBImpl.html
# -rw-r--r--   1 1000 1000       5577 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/records/impl/pb/class-use/DisabledNameservicePBImpl.html
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/driver
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/driver/class-use
# -rw-r--r--   1 1000 1000      14667 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/driver/class-use/StateStoreDriver.html
# -rw-r--r--   1 1000 1000      11380 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/driver/class-use/StateStoreSerializer.html
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/hadoop-project-dist/hadoop-hdfs-rbf/build/source/hadoop-hdfs-project/hadoop-hdfs-rbf/target/api/org/apache/hadoop/hdfs/server/federation/store/driver/impl
# ...
# -rw-r--r--   1 1000 1000       4557 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/minikdc/package-tree.html
# -rw-r--r--   1 1000 1000       4289 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/minikdc/package-use.html
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/http
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/http/class-use
# -rw-r--r--   1 1000 1000       4628 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/http/class-use/JettyUtils.html
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/http/lib
# -rw-r--r--   1 1000 1000       5344 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/http/lib/package-summary.html
# -rw-r--r--   1 1000 1000        738 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/http/lib/package-frame.html
# -rw-r--r--   1 1000 1000       4623 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/http/lib/package-tree.html
# -rw-r--r--   1 1000 1000       4338 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/http/lib/package-use.html
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/util
# -rw-r--r--   1 1000 1000      23107 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/util/SysInfo.html
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/util/class-use
# -rw-r--r--   1 1000 1000       6622 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/util/class-use/SysInfo.html
# -rw-r--r--   1 1000 1000       4635 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/util/class-use/PureJavaCrc32.html
# -rw-r--r--   1 1000 1000       6720 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/util/class-use/OperationDuration.html
# -rw-r--r--   1 1000 1000       6793 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/util/class-use/Shell.html
# -rw-r--r--   1 1000 1000       4657 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/util/class-use/ReflectionUtils.html
# -rw-r--r--   1 1000 1000      22473 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/util/class-use/Tool.html
# -rw-r--r--   1 1000 1000       4582 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/util/class-use/IPList.html
# -rw-r--r--   1 1000 1000       4646 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/util/class-use/StringInterner.html
# -rw-r--r--   1 1000 1000       6869 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/util/class-use/ShutdownHookManager.html
# -rw-r--r--   1 1000 1000       4602 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/util/class-use/ToolRunner.html
# -rw-r--r--   1 1000 1000       4613 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/util/class-use/VersionInfo.html
# -rw-r--r--   1 1000 1000       6791 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/util/class-use/ApplicationClassLoader.html
# -rw-r--r--   1 1000 1000       4624 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/util/class-use/DurationInfo.html
# -rw-r--r--   1 1000 1000     106673 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/util/class-use/Progressable.html
# -rw-r--r--   1 1000 1000       4646 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/util/class-use/PureJavaCrc32C.html
# -rw-r--r--   1 1000 1000      15742 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/util/PureJavaCrc32.html
# -rw-r--r--   1 1000 1000      10242 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/util/package-summary.html
# -rw-r--r--   1 1000 1000      18161 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/util/OperationDuration.html
# -rw-r--r--   1 1000 1000      98140 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/util/Shell.html
# -rw-r--r--   1 1000 1000      28493 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/util/ReflectionUtils.html
# -rw-r--r--   1 1000 1000      13288 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/util/Tool.html
# -rw-r--r--   1 1000 1000       8393 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/util/IPList.html
# -rw-r--r--   1 1000 1000      16166 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/util/StringInterner.html
# -rw-r--r--   1 1000 1000      22500 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/util/ShutdownHookManager.html
# -rw-r--r--   1 1000 1000      19699 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/util/ToolRunner.html
# -rw-r--r--   1 1000 1000      29030 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/util/VersionInfo.html
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/util/curator
# -rw-r--r--   1 1000 1000       5145 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/util/curator/package-summary.html
# -rw-r--r--   1 1000 1000        750 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/util/curator/package-frame.html
# -rw-r--r--   1 1000 1000       4653 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/util/curator/package-tree.html
# -rw-r--r--   1 1000 1000       4366 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/util/curator/package-use.html
# -rw-r--r--   1 1000 1000       2711 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/util/package-frame.html
# drwxr-xr-x   - 1000 1000       4096 2023-06-18 09:37 hadoop-3.3.6/share/doc/hadoop/api/org/apache/hadoop/util/bloom
# -ls: Fatal internal error
# java.lang.RuntimeException: Error while running command to get file permissions : ExitCodeException exitCode=130:
# 	at org.apache.hadoop.util.Shell.runCommand(Shell.java:1068)
# 	at org.apache.hadoop.util.Shell.run(Shell.java:957)
# 	at org.apache.hadoop.util.Shell$ShellCommandExecutor.execute(Shell.java:1282)
# 	at org.apache.hadoop.util.Shell.execCommand(Shell.java:1377)
# 	at org.apache.hadoop.util.Shell.execCommand(Shell.java:1359)
# 	at org.apache.hadoop.fs.FileUtil.execCommand(FileUtil.java:1513)
# 	at org.apache.hadoop.fs.RawLocalFileSystem$DeprecatedRawLocalFileStatus.loadPermissionInfoByNonNativeIO(RawLocalFileSystem.java:1000)
# 	at org.apache.hadoop.fs.RawLocalFileSystem$DeprecatedRawLocalFileStatus.loadPermissionInfo(RawLocalFileSystem.java:991)
# 	at org.apache.hadoop.fs.RawLocalFileSystem$DeprecatedRawLocalFileStatus.getOwner(RawLocalFileSystem.java:960)
# 	at org.apache.hadoop.fs.shell.Ls.adjustColumnWidths(Ls.java:332)
# 	at org.apache.hadoop.fs.shell.Ls.processPaths(Ls.java:280)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:373)
# 	at org.apache.hadoop.fs.shell.Command.recursePath(Command.java:456)
# 	at org.apache.hadoop.fs.shell.Command.processPathInternal(Command.java:384)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:345)
# 	at org.apache.hadoop.fs.shell.Ls.processPaths(Ls.java:282)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:373)
# 	at org.apache.hadoop.fs.shell.Command.recursePath(Command.java:456)
# 	at org.apache.hadoop.fs.shell.Command.processPathInternal(Command.java:384)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:345)
# 	at org.apache.hadoop.fs.shell.Ls.processPaths(Ls.java:282)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:373)
# 	at org.apache.hadoop.fs.shell.Command.recursePath(Command.java:456)
# 	at org.apache.hadoop.fs.shell.Command.processPathInternal(Command.java:384)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:345)
# 	at org.apache.hadoop.fs.shell.Ls.processPaths(Ls.java:282)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:373)
# 	at org.apache.hadoop.fs.shell.Command.recursePath(Command.java:456)
# 	at org.apache.hadoop.fs.shell.Command.processPathInternal(Command.java:384)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:345)
# 	at org.apache.hadoop.fs.shell.Ls.processPaths(Ls.java:282)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:373)
# 	at org.apache.hadoop.fs.shell.Command.recursePath(Command.java:456)
# 	at org.apache.hadoop.fs.shell.Command.processPathInternal(Command.java:384)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:345)
# 	at org.apache.hadoop.fs.shell.Ls.processPaths(Ls.java:282)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:373)
# 	at org.apache.hadoop.fs.shell.Command.recursePath(Command.java:456)
# 	at org.apache.hadoop.fs.shell.Command.processPathInternal(Command.java:384)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:345)
# 	at org.apache.hadoop.fs.shell.Ls.processPaths(Ls.java:282)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:373)
# 	at org.apache.hadoop.fs.shell.Command.recursePath(Command.java:456)
# 	at org.apache.hadoop.fs.shell.Command.processPathInternal(Command.java:384)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:345)
# 	at org.apache.hadoop.fs.shell.Ls.processPaths(Ls.java:282)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:373)
# 	at org.apache.hadoop.fs.shell.Command.recursePath(Command.java:456)
# 	at org.apache.hadoop.fs.shell.Command.processPathInternal(Command.java:384)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:345)
# 	at org.apache.hadoop.fs.shell.Ls.processPaths(Ls.java:282)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:373)
# 	at org.apache.hadoop.fs.shell.Command.recursePath(Command.java:456)
# 	at org.apache.hadoop.fs.shell.Command.processPathInternal(Command.java:384)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:345)
# 	at org.apache.hadoop.fs.shell.Ls.processPaths(Ls.java:282)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:373)
# 	at org.apache.hadoop.fs.shell.Command.recursePath(Command.java:456)
# 	at org.apache.hadoop.fs.shell.Command.processPathInternal(Command.java:384)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:345)
# 	at org.apache.hadoop.fs.shell.Ls.processPaths(Ls.java:282)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:373)
# 	at org.apache.hadoop.fs.shell.Command.recursePath(Command.java:456)
# 	at org.apache.hadoop.fs.shell.Ls.processPathArgument(Ls.java:242)
# 	at org.apache.hadoop.fs.shell.Command.processArgument(Command.java:300)
# 	at org.apache.hadoop.fs.shell.Command.processArguments(Command.java:284)
# 	at org.apache.hadoop.fs.shell.FsCommand.processRawArguments(FsCommand.java:121)
# 	at org.apache.hadoop.fs.shell.Command.run(Command.java:191)
# 	at org.apache.hadoop.fs.FsShell.run(FsShell.java:327)
# 	at org.apache.hadoop.util.ToolRunner.run(ToolRunner.java:82)
# 	at org.apache.hadoop.util.ToolRunner.run(ToolRunner.java:97)
# 	at org.apache.hadoop.fs.FsShell.main(FsShell.java:390)
#
# 	at org.apache.hadoop.fs.RawLocalFileSystem$DeprecatedRawLocalFileStatus.loadPermissionInfoByNonNativeIO(RawLocalFileSystem.java:1040)
# 	at org.apache.hadoop.fs.RawLocalFileSystem$DeprecatedRawLocalFileStatus.loadPermissionInfo(RawLocalFileSystem.java:991)
# 	at org.apache.hadoop.fs.RawLocalFileSystem$DeprecatedRawLocalFileStatus.getOwner(RawLocalFileSystem.java:960)
# 	at org.apache.hadoop.fs.shell.Ls.adjustColumnWidths(Ls.java:332)
# 	at org.apache.hadoop.fs.shell.Ls.processPaths(Ls.java:280)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:373)
# 	at org.apache.hadoop.fs.shell.Command.recursePath(Command.java:456)
# 	at org.apache.hadoop.fs.shell.Command.processPathInternal(Command.java:384)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:345)
# 	at org.apache.hadoop.fs.shell.Ls.processPaths(Ls.java:282)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:373)
# 	at org.apache.hadoop.fs.shell.Command.recursePath(Command.java:456)
# 	at org.apache.hadoop.fs.shell.Command.processPathInternal(Command.java:384)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:345)
# 	at org.apache.hadoop.fs.shell.Ls.processPaths(Ls.java:282)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:373)
# 	at org.apache.hadoop.fs.shell.Command.recursePath(Command.java:456)
# 	at org.apache.hadoop.fs.shell.Command.processPathInternal(Command.java:384)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:345)
# 	at org.apache.hadoop.fs.shell.Ls.processPaths(Ls.java:282)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:373)
# 	at org.apache.hadoop.fs.shell.Command.recursePath(Command.java:456)
# 	at org.apache.hadoop.fs.shell.Command.processPathInternal(Command.java:384)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:345)
# 	at org.apache.hadoop.fs.shell.Ls.processPaths(Ls.java:282)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:373)
# 	at org.apache.hadoop.fs.shell.Command.recursePath(Command.java:456)
# 	at org.apache.hadoop.fs.shell.Command.processPathInternal(Command.java:384)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:345)
# 	at org.apache.hadoop.fs.shell.Ls.processPaths(Ls.java:282)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:373)
# 	at org.apache.hadoop.fs.shell.Command.recursePath(Command.java:456)
# 	at org.apache.hadoop.fs.shell.Command.processPathInternal(Command.java:384)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:345)
# 	at org.apache.hadoop.fs.shell.Ls.processPaths(Ls.java:282)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:373)
# 	at org.apache.hadoop.fs.shell.Command.recursePath(Command.java:456)
# 	at org.apache.hadoop.fs.shell.Command.processPathInternal(Command.java:384)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:345)
# 	at org.apache.hadoop.fs.shell.Ls.processPaths(Ls.java:282)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:373)
# 	at org.apache.hadoop.fs.shell.Command.recursePath(Command.java:456)
# 	at org.apache.hadoop.fs.shell.Command.processPathInternal(Command.java:384)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:345)
# 	at org.apache.hadoop.fs.shell.Ls.processPaths(Ls.java:282)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:373)
# 	at org.apache.hadoop.fs.shell.Command.recursePath(Command.java:456)
# 	at org.apache.hadoop.fs.shell.Command.processPathInternal(Command.java:384)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:345)
# 	at org.apache.hadoop.fs.shell.Ls.processPaths(Ls.java:282)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:373)
# 	at org.apache.hadoop.fs.shell.Command.recursePath(Command.java:456)
# 	at org.apache.hadoop.fs.shell.Command.processPathInternal(Command.java:384)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:345)
# 	at org.apache.hadoop.fs.shell.Ls.processPaths(Ls.java:282)
# 	at org.apache.hadoop.fs.shell.Command.processPaths(Command.java:373)
# 	at org.apache.hadoop.fs.shell.Command.recursePath(Command.java:456)
# 	at org.apache.hadoop.fs.shell.Ls.processPathArgument(Ls.java:242)
# 	at org.apache.hadoop.fs.shell.Command.processArgument(Command.java:300)
# 	at org.apache.hadoop.fs.shell.Command.processArguments(Command.java:284)
# 	at org.apache.hadoop.fs.shell.FsCommand.processRawArguments(FsCommand.java:121)
# 	at org.apache.hadoop.fs.shell.Command.run(Command.java:191)
# 	at org.apache.hadoop.fs.FsShell.run(FsShell.java:327)
# 	at org.apache.hadoop.util.ToolRunner.run(ToolRunner.java:82)
# 	at org.apache.hadoop.util.ToolRunner.run(ToolRunner.java:97)
# 	at org.apache.hadoop.fs.FsShell.main(FsShell.java:390)

# %% [markdown]
# - Crear un fichero local :

# %% [markdown]
# **nota**: se puede utilizar el signo ! para introducir comandos bash o utilizar el elemento %%bash que hará que toda la celda se considere y se ejecute como un script de bash

# %%
# %%bash
# echo "Ejemplo de HDFS" > user.txt
# echo `date` >> user.txt
# cat user.txt
# Out:
# Ejemplo de HDFS
# Tue Jan 23 09:12:54 AM UTC 2024

# %% [markdown]
# - Colocarlo (copiarlo)  en el directorio *prueba*

# %%
# !/usr/local/hadoop-3.3.6/bin/hadoop fs -put user.txt prueba/
# Out:
# user.txt

# %% [markdown]
# - Mostrar su contenido

# %%
# !/usr/local/hadoop-3.3.6/bin/hadoop fs -cat prueba/user.txt
# Out:
# Ejemplo de HDFS
# Tue Jan 23 09:12:54 AM UTC 2024

# %%
# %%bash
# /usr/local/hadoop-3.3.6/bin/hdfs dfs -tail prueba/user.txt
# Out:
# Ejemplo de HDFS
# Tue Jan 23 09:12:54 AM UTC 2024

# %% [markdown]
# ## Ejercicio

# %% [markdown]
# 1. Cree un directorio `files` en HDFS.
# 2. Listar el contenido de un directorio /.
# 3. Cargar el archivo today.txt en HDFS.
# ```bash
# date > hoy.txt
# whoami >> hoy.txt
# ```
# 4. Mostrar el contenido del archivo `hoy.txt`.
# 5. Copiar el archivo `hoy.txt` del origen al directorio `files`.
# 6. Copiar el archivo `jps.txt` desde/hacia el sistema de archivos local a HDFS
# ```bash
# jps > jps.txt
# ```
# 7. Mover el archivo `jps.txt` de la fuente a `files`.
# 8. Eliminar el archivo `today.txt` del directorio principal en HDFS.
# 9. Mostrar las últimas líneas de `jps.txt`.
